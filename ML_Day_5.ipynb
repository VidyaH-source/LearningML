# %%
print("Pandas")
# Out:
# Pandas

# %%
import pandas as pd
#with list
l= [10,20,30,40,50]

df = pd. DataFrame(l)      #have not specified columns and index

print(df)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
data = {"calories":[420,380,390], "duration":[50,40,45]} #keys will be columns and values will be data
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
l= [[10,20,30,40,50],[100,200,300,400,500]]

df = pd. DataFrame(l)      #have not specified columns and index

print(df)
# Out:
#      0    1    2    3    4
# 0   10   20   30   40   50
# 1  100  200  300  400  500

# %%
l= [[10,20,30,40,50],[100,200,300,400,500,600]]

df = pd. DataFrame(l)      #Nan is Not a Number

print(df)
# Out:
#      0    1    2    3    4      5
# 0   10   20   30   40   50    NaN
# 1  100  200  300  400  500  600.0

# %%
l= [[[10,20,30,40,50],[111,222,333,444,555,666]],[[100,200,300,400,500,600],[11,22,33,44,55]]]

df = pd. DataFrame(l)

print(df)
# Out:
#                                 0                               1
# 0            [10, 20, 30, 40, 50]  [111, 222, 333, 444, 555, 666]
# 1  [100, 200, 300, 400, 500, 600]            [11, 22, 33, 44, 55]

# %%
l= [[[10,20,30,40,50],[111,222,333,444,555,666]],[[100,200,300,400,500,600],[11,22,33,44,55]]]

df = pd. DataFrame(l, index = ["a","b"], columns = ["c","d"])

print(df)
# Out:
#                                 c                               d
# a            [10, 20, 30, 40, 50]  [111, 222, 333, 444, 555, 666]
# b  [100, 200, 300, 400, 500, 600]            [11, 22, 33, 44, 55]

# %%
l= [[[10,20,30,40,50],[111,222,333,444,555,666]],[[100,200,300,400,500,600],[11,22,33,44,55]]]

df = pd. DataFrame(l, index = ["a","b"], columns = ["c","d", "e"])

print(df)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     938     try:
# --> 939         columns = _validate_or_indexify_columns(contents, columns)
#     940     except AssertionError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     985             # caller's responsibility to check for this...
# --> 986             raise AssertionError(
#     987                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
l= [[[10,20,30,40,50],[111,222,333,444,555,666]],[[100,200,300,400,500,600],[11,22,33,44,55]]]

df = pd. DataFrame(l, index = ["a","b"], columns = ["c","d"])

print(df)
# Out:
#                                 c                               d
# a            [10, 20, 30, 40, 50]  [111, 222, 333, 444, 555, 666]
# b  [100, 200, 300, 400, 500, 600]            [11, 22, 33, 44, 55]

# %%
from numpy.random import randn
df = pd.DataFrame(randn(5,4), index ='A B C D E'.split(), columns=["w","x","y","z"])
df
# Out:
#           w         x         y         z
# A -1.687170 -1.023113 -0.821355  0.537312
# B  2.167333  0.824601  1.554449  1.555560
# C  1.462707 -0.273663 -0.280610 -0.808417
# D  0.756676  0.986458  0.301171 -1.464290
# E  0.423038 -1.432486  0.860290  0.345898

# %%
from numpy.random import randn
import numpy as np
np.random.seed(101)
df = pd.DataFrame(randn(5,4), index ='A B C D E'.split(), columns=["w","x","y","z"])
df
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
import numpy as np
w = np.random.seed(101)
print(w)
# Out:
# None

# %%
ran_num = np.random.normal(0,1,1)
print("random number", ran_num)
# Out:
# random number [2.70684984]

# %%
from numpy.random import randn
df = pd.DataFrame(randn(5,4), index ='A B C D E'.split(), columns=["w","x","y","z"])
df
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168
# C  0.740122  0.528813 -0.589001  0.188695
# D -0.758872 -0.933237  0.955057  0.190794
# E  1.978757  2.605967  0.683509  0.302665

# %%
df['x']
# Out:
# A    0.907969
# B   -0.848077
# C    0.528813
# D   -0.933237
# E    2.605967
# Name: x, dtype: float64

# %%
df[['x','y']]
# Out:
#           x         y
# A  0.907969  0.503826
# B -0.848077  0.605965
# C  0.528813 -0.589001
# D -0.933237  0.955057
# E  2.605967  0.683509

# %%
df['n'] = df['x'] + df['z']
df
# Out:
#           w         x         y         z         n
# A  0.628133  0.907969  0.503826  0.651118  1.559087
# B -0.319318 -0.848077  0.605965 -2.018168 -2.866245
# C  0.740122  0.528813 -0.589001  0.188695  0.717509
# D -0.758872 -0.933237  0.955057  0.190794 -0.742443
# E  1.978757  2.605967  0.683509  0.302665  2.908633

# %%
#delete a column result is view

df.drop('n', axis = 1)
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168
# C  0.740122  0.528813 -0.589001  0.188695
# D -0.758872 -0.933237  0.955057  0.190794
# E  1.978757  2.605967  0.683509  0.302665

# %%
df
# Out:
#           w         x         y         z         n
# A  0.628133  0.907969  0.503826  0.651118  1.559087
# B -0.319318 -0.848077  0.605965 -2.018168 -2.866245
# C  0.740122  0.528813 -0.589001  0.188695  0.717509
# D -0.758872 -0.933237  0.955057  0.190794 -0.742443
# E  1.978757  2.605967  0.683509  0.302665  2.908633

# %%
#to drop the column and make it permanent
df.drop('n', axis = 1, inplace = True)

# %%
df
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168
# C  0.740122  0.528813 -0.589001  0.188695
# D -0.758872 -0.933237  0.955057  0.190794
# E  1.978757  2.605967  0.683509  0.302665

# %%
#Rows , loc is locate

df.loc['A']
# Out:
# w    0.628133
# x    0.907969
# y    0.503826
# z    0.651118
# Name: A, dtype: float64

# %%
df.iloc[1]
# Out:
# w   -0.319318
# x   -0.848077
# y    0.605965
# z   -2.018168
# Name: B, dtype: float64

# %%
df.iloc[0]
# Out:
# w    0.628133
# x    0.907969
# y    0.503826
# z    0.651118
# Name: A, dtype: float64

# %%
#how to fetch as subset

df.loc['C','y']
# Out:
# -0.5890005332865824

# %%
df.loc[['B','C'],['x','y']]
# Out:
#           x         y
# B -0.848077  0.605965
# C  0.528813 -0.589001

# %%
#Conditional Selection
df > 0
# Out:
#        w      x      y      z
# A   True   True   True   True
# B  False  False   True  False
# C   True   True  False   True
# D  False  False   True   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# B       NaN       NaN  0.605965       NaN
# C  0.740122  0.528813       NaN  0.188695
# D       NaN       NaN  0.955057  0.190794
# E  1.978757  2.605967  0.683509  0.302665

# %%
df[df['w']>0]
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# C  0.740122  0.528813 -0.589001  0.188695
# E  1.978757  2.605967  0.683509  0.302665

# %%
df
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168
# C  0.740122  0.528813 -0.589001  0.188695
# D -0.758872 -0.933237  0.955057  0.190794
# E  1.978757  2.605967  0.683509  0.302665

# %%
dd = df[df['w']>0]
print(dd)
print(type(dd))
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# C  0.740122  0.528813 -0.589001  0.188695
# E  1.978757  2.605967  0.683509  0.302665
# <class 'pandas.core.frame.DataFrame'>

# %%
dd
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# C  0.740122  0.528813 -0.589001  0.188695
# E  1.978757  2.605967  0.683509  0.302665

# %%
df
# Out:
#           w         x         y         z
# A  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168
# C  0.740122  0.528813 -0.589001  0.188695
# D -0.758872 -0.933237  0.955057  0.190794
# E  1.978757  2.605967  0.683509  0.302665

# %%
dd = df[df['w']>0]['y']
print(dd)
print(type(dd))
# Out:
# A    0.503826
# C   -0.589001
# E    0.683509
# Name: y, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
dd
# Out:
# A    0.503826
# C   -0.589001
# E    0.683509
# Name: y, dtype: float64

# %%
dd = df[df['w']>0][['y','z']]
print(dd)
print(type(dd))
# Out:
#           y         z
# A  0.503826  0.651118
# C -0.589001  0.188695
# E  0.683509  0.302665
# <class 'pandas.core.frame.DataFrame'>

# %%
dd = df[(df['w']>0) & df['y']>1]
dd
# Out:
# Empty DataFrame
# Columns: [w, x, y, z]
# Index: []

# %%
dd2 = df[(df['w']>0) & df['y']>0]
print(dd2)
# Out:
#           w         x         y         z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# resetting index

df.reset_index(inplace = True)
df
# Out:
#   index         w         x         y         z
# 0     A  0.628133  0.907969  0.503826  0.651118
# 1     B -0.319318 -0.848077  0.605965 -2.018168
# 2     C  0.740122  0.528813 -0.589001  0.188695
# 3     D -0.758872 -0.933237  0.955057  0.190794
# 4     E  1.978757  2.605967  0.683509  0.302665

# %%
df = pd.read_csv('data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 1000

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head() #first 5
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.head(25) #first 25
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# ...

# %%
df.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
# Day 6
print("Day 6 Start")
# Out:
# Day 6 Start

# %%
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
dff = pd.read_csv('dirtydata.csv')
print(dff)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
print(dff.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB
# None

# %%
#Cleaning Data
print("Cleaning data")
# Out:
# Cleaning data

# %%
print(dff.describe()) #since date is an object, it is not handled here
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
dff
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Cleaning data

x = dff.dropna()  #remove row which has 'NaN
print(x)
print(type(x))
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dff
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dff.dropna(inplace=True)
print(dff)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
import numpy as np

data = {'col1':[1,np.nan,3],
        'col2':[4,5,np.nan],
        'col3':[7,8,9]}
df = pd.DataFrame(data)

print(df)
missing_values = df.isna()

print(missing_values)
# Out:
#    col1  col2  col3
# 0   1.0   4.0     7
# 1   NaN   5.0     8
# 2   3.0   NaN     9
#     col1   col2   col3
# 0  False  False  False
# 1   True  False  False
# 2  False   True  False

# %%
df_nan = dff[dff.isna()]
print(df_nan)
# Out:
#     Duration Date  Pulse  Maxpulse  Calories
# 0        NaN  NaN    NaN       NaN       NaN
# 1        NaN  NaN    NaN       NaN       NaN
# 2        NaN  NaN    NaN       NaN       NaN
# 3        NaN  NaN    NaN       NaN       NaN
# 4        NaN  NaN    NaN       NaN       NaN
# 5        NaN  NaN    NaN       NaN       NaN
# 6        NaN  NaN    NaN       NaN       NaN
# 7        NaN  NaN    NaN       NaN       NaN
# 8        NaN  NaN    NaN       NaN       NaN
# 9        NaN  NaN    NaN       NaN       NaN
# 10       NaN  NaN    NaN       NaN       NaN
# 11       NaN  NaN    NaN       NaN       NaN
# 12       NaN  NaN    NaN       NaN       NaN
# 13       NaN  NaN    NaN       NaN       NaN
# 14       NaN  NaN    NaN       NaN       NaN
# 15       NaN  NaN    NaN       NaN       NaN
# 16       NaN  NaN    NaN       NaN       NaN
# 17       NaN  NaN    NaN       NaN       NaN
# 19       NaN  NaN    NaN       NaN       NaN
# 20       NaN  NaN    NaN       NaN       NaN
# ...

# %%
df_nan = dff.isna()
print(df_nan)
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 19     False  False  False     False     False
# ...

# %%
dff
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df_nan = dff[dff.isna().any(axis=1)] #if axis = 1 processing through column wise
print(df_nan)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 18        45  '2020/12/18'     90       112       NaN
# 22        45           NaN    100       119     282.0
# 28        60  '2020/12/28'    103       132       NaN

# %%
df_nan = dff[dff.isna().any(axis=0)]
print(df_nan)
# Out:
# <ipython-input-39-b7be3d874f57>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_nan = dff[dff.isna().any(axis=0)]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-39-b7be3d874f57> in <cell line: 1>()
# ----> 1 df_nan = dff[dff.isna().any(axis=0)]
#       2 print(df_nan)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
# -> 4093             return self._getitem_bool_array(key)
#    4094
#    4095         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    4147         # check_bool_indexer will throw exception if Series key cannot
# ...

# %%
dff
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
x = dff['Calories'].mean()
print(x)
print(type(x))
# Out:
# 304.68
# <class 'numpy.float64'>

# %%
dff['Calories'].fillna(x,inplace= True)
print(dff)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
dff = pd.read_csv("dirtydata.csv")
x= dff['Calories'].median()
print(x)
print(type(x))
# Out:
# 291.2
# <class 'float'>

# %%
dff = pd.read_csv("dirtydata.csv")
x= dff['Calories'].mode()
print(x)
print(type(x))
# Out:
# 0    300.0
# Name: Calories, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
x= dff['Calories'].mode()
print(x)
print(type(x))

dff['Calories'].fillna(x,inplace= True)
dff
# Out:
# 0    300.0
# Name: Calories, dtype: float64
# <class 'pandas.core.series.Series'>
# <ipython-input-50-ce324d2bc8cf>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dff['Calories'].fillna(x,inplace= True)
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# ...

# %%
x= dff['Calories'].mode()[0]
print(x)
print(type(x))

dff['Calories'].fillna(x,inplace= True)
dff
# Out:
# 300.0
# <class 'numpy.float64'>
# <ipython-input-52-a9194141f42e>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dff['Calories'].fillna(x,inplace= True)
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# ...

# %%
dff = pd.read_csv("dirtydata.csv")
x= dff['Calories'].mode()
print(x)
print(type(x))
# Out:
# 0    300.0
# Name: Calories, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
dff = pd.read_csv("dirtydata.csv")
x= dff['Calories'].mode()
print('For calories',x)
print(type(x))

y = dff['Pulse'].mode()
print('For Pulse', y)
print(type(y))
# Out:
# For calories 0    300.0
# Name: Calories, dtype: float64
# <class 'pandas.core.series.Series'>
# For Pulse 0    100
# Name: Pulse, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#Cleaning Wrong formatted data

dff = pd.read_csv("dirtydata.csv")
dff['Date'] = pd.to_datetime(dff['Date'])
print(dff)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-e47ec867fc10> in <cell line: 4>()
#       2
#       3 dff = pd.read_csv("dirtydata.csv")
# ----> 4 dff['Date'] = pd.to_datetime(dff['Date'])
#       5 print(dff)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065             result = arg.map(cache_array)
#    1066         else:
# -> 1067             values = convert_listlike(arg._values, format)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
dff['Date'] = pd.to_datetime(dff['Date'],format = 'mixed')
print(dff)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
dff.dropna(subset=['Date'], inplace = True)
print(dff)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
dff.dropna(subset=['Date','Calories'], inplace = True)
print(dff)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
dff.loc[7,'Duration'] = 150
dff
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        150 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
for x in dff.index:
  if dff.loc[x,"Duration"] > 70:
     dff.loc[x, "Duration"] = 70

print(dff)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         70 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
for x in dff.index:
  if dff.loc[x,'Duration'] > 60:
    dff.drop(x, inplace = True)
print(dff)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %%
dff
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %%
import pandas as pd
df = pd.read_csv("dirtydata.csv")
